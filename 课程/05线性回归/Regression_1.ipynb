# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
x = np.array([ 338, 333, 328, 207, 226, 25, 179, 60, 208, 606]).reshape(-1, 1)
y = np.array([ 640, 633, 619, 393, 428, 27, 193, 66, 226, 1591]).reshape(-1, 1)

# %%
# 使用sklearn.cross_valiation里的train_test_split模块用于分割数据。
from sklearn.cross_validation import train_test_split

# 随机采样50%的数据用于测试，剩下的50%用于构建训练集合。
x_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=33)

# %%
plt.scatter(X_train, y_train, marker='o',c = 'red')
plt.scatter(X_test, y_test, marker='x',c = 'black')
plt.xlabel("x")
plt.ylabel("y")
#plt.savefig("image_4.png")
# Out:
# Text(0,0.5,'y')

# %%
plt.plot(X_test, 0.5*X_test+100, 'r-')
plt.plot(X_test, 3.9*X_test-100, 'b-')
plt.plot(X_test, 2.1*X_test-100, 'g-')
plt.scatter(X_train, y_train, marker='o',c = 'red')
plt.scatter(X_test, y_test, marker='x',c = 'black')
plt.xlabel("x")
plt.ylabel("y")
plt.savefig("./image/image_8.png") 
plt.show()

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred_1 = lr.predict(X_test)
y_pred_0 = lr.predict(X_train)
print('Slope: %.3f' % lr.coef_)
print('Intercept: %.3f' % lr.intercept_)
e_train = sum((y_pred_0 - y_train)**2) / (2*len(y_train))
print('error(train): %.3f' % ( sum((y_pred_0 - y_train)**2) / (2*len(y_train))))
print('error(train): %.3f' % ( sum((y_pred_1 - y_test)**2) / (2*len(y_test))))
# Out:
# Slope: 2.170
# Intercept: -101.718
# error(train): 1188.229
# error(train): 16558.387

# %%
plt.plot(X_test, y_pred_1, 'r-')
plt.scatter(X_train, y_train, marker='o',c = 'red')
plt.scatter(X_test, y_test, marker='x',c = 'black')
plt.xlabel("x")
plt.ylabel("y")
plt.savefig("./image/image_5.png") 
plt.show()

# %%
x = [ 338, 333, 328, 207, 226, 25, 179, 60, 208, 606]
x = np.array((x,[i*i for i in x ])).T
y = np.array([ 640, 633, 619, 393, 428, 27, 193, 66, 226, 1591])

# %%
# 使用sklearn.cross_valiation里的train_test_split模块用于分割数据。
from sklearn.cross_validation import train_test_split

# 随机采样50%的数据用于测试，剩下的50%用于构建训练集合。
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=33)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred_1 = lr.predict(X_test)
y_pred_0 = lr.predict(X_train)
print(lr.coef_)
print(lr.intercept_)
e_train = sum((y_pred_0 - y_train)**2) / (2*len(y_train))
print('error(train): %.3f' % ( sum((y_pred_0 - y_train)**2) / (2*len(y_train))))
print('error(train): %.3f' % ( sum((y_pred_1 - y_test)**2) / (2*len(y_test))))
# Out:
# [1.07030769 0.00268394]
# -18.52673150106756
# error(train): 914.230
# error(train): 1540.624

# %%
# Out:
# numpy.ndarray

# %%
x = np.array((x,[i*i for i in x ])).T
plt.plot(range(600), lr.predict(np.array((range(600),[i*i for i in range(600) ])).T), 'r-')
plt.scatter(X_train[:,0], y_train, marker='o',c = 'red')
plt.scatter(X_test[:,0], y_test, marker='x',c = 'black')
plt.xlabel("x")
plt.ylabel("y")
plt.savefig("./image/image_6.png") 
plt.show()

# %%
x = [ 338, 333, 328, 207, 226, 25, 179, 60, 208, 606]
x = np.array((x,[i*i for i in x ],[i*i*i for i in x ])).T
y = np.array([ 640, 633, 619, 393, 428, 27, 193, 66, 226, 1591])

# 使用sklearn.cross_valiation里的train_test_split模块用于分割数据。
from sklearn.cross_validation import train_test_split

# 随机采样50%的数据用于测试，剩下的50%用于构建训练集合。
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=33)

from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred_1 = lr.predict(X_test)
y_pred_0 = lr.predict(X_train)
print(lr.coef_)
print(lr.intercept_)
e_train = sum((y_pred_0 - y_train)**2) / (2*len(y_train))
print('error(train): %.3f' % ( sum((y_pred_0 - y_train)**2) / (2*len(y_train))))
print('error(train): %.3f' % ( sum((y_pred_1 - y_test)**2) / (2*len(y_test))))
# Out:
# [-1.29120717e+01  8.57787934e-02 -1.39215698e-04]
# 561.3536418257611
# error(train): 105.147
# error(train): 6955811.737

# %%
plt.plot(range(600), lr.predict(np.array((range(600),[i*i for i in range(600)],[i*i*i for i in range(600)])).T), 'r-')
plt.scatter(X_train[:,0], y_train, marker='o',c = 'red')
plt.scatter(X_test[:,0], y_test, marker='x',c = 'black')
plt.xlabel("x")
plt.ylabel("y")
plt.savefig("./image/image_7.png") 
plt.show()

# %%
x = [ 338, 333, 328, 207, 226, 25, 179, 60, 208, 606]
x = np.array((x,[i*i for i in x ],[i*i*i for i in x ])).T
y = np.array([ 640, 633, 619, 393, 428, 27, 193, 66, 226, 1591])

# 使用sklearn.cross_valiation里的train_test_split模块用于分割数据。
from sklearn.cross_validation import train_test_split

# 随机采样50%的数据用于测试，剩下的50%用于构建训练集合。
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=33)

from sklearn import linear_model

lr = linear_model.Ridge(90000000)
lr.fit(X_train,y_train)
y_pred_1 = lr.predict(X_test)
y_pred_0 = lr.predict(X_train)
print(lr.coef_)
print(lr.intercept_)
e_train = sum((y_pred_0 - y_train)**2) / (2*len(y_train))
print('error(train): %.3f' % ( sum((y_pred_0 - y_train)**2) / (2*len(y_train))))
print('error(train): %.3f' % ( sum((y_pred_1 - y_test)**2) / (2*len(y_test))))
# Out:
# [ 3.20524412e-05  6.44694903e-03 -3.65271612e-06]
# 58.12709410699097
# error(train): 983.406
# error(train): 1613.133

# %%
plt.plot(range(600), lr.predict(np.array((range(600),[i*i for i in range(600)],[i*i*i for i in range(600)])).T), 'r-')
plt.scatter(X_train[:,0], y_train, marker='o',c = 'red')
plt.scatter(X_test[:,0], y_test, marker='x',c = 'black')
plt.xlabel("x")
plt.ylabel("y")
plt.savefig("./image/image_9.png") 
plt.show()

# %%
x = [ 338, 333, 328, 207, 226, 25, 179, 60, 208, 606]
x = np.array((x,[i*i for i in x ],[i*i*i for i in x ])).T
y = np.array([ 640, 633, 619, 393, 428, 27, 193, 66, 226, 1591])

# 使用sklearn.cross_valiation里的train_test_split模块用于分割数据。
from sklearn.cross_validation import train_test_split

# 随机采样50%的数据用于测试，剩下的50%用于构建训练集合。
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=33)

from sklearn import linear_model

lr = linear_model.Lasso(alpha = 100000)
lr.fit(X_train,y_train)
y_pred_1 = lr.predict(X_test)
y_pred_0 = lr.predict(X_train)
print(lr.coef_)
print(lr.intercept_)
e_train = sum((y_pred_0 - y_train)**2) / (2*len(y_train))
print('error(train): %.3f' % ( sum((y_pred_0 - y_train)**2) / (2*len(y_train))))
print('error(train): %.3f' % ( sum((y_pred_1 - y_test)**2) / (2*len(y_test))))
# Out:
# [ 0.00000000e+00  6.88151316e-03 -4.83111475e-06]
# 52.85813778231585
# error(train): 936.153
# error(train): 2269.068

# %%
plt.plot(range(600), lr.predict(np.array((range(600),[i*i for i in range(600)],[i*i*i for i in range(600)])).T), 'r-')
plt.scatter(X_train[:,0], y_train, marker='o',c = 'red')
plt.scatter(X_test[:,0], y_test, marker='x',c = 'black')
plt.xlabel("x")
plt.ylabel("y")
plt.savefig("./image/image_10.png") 
plt.show()

# %%
x = [ 338, 333, 328, 207, 226, 25, 179, 60, 208, 606]
x = np.array((x,[i*i for i in x ],[i*i*i for i in x ])).T
y = np.array([ 640, 633, 619, 393, 428, 27, 193, 66, 226, 1591])

# 使用sklearn.cross_valiation里的train_test_split模块用于分割数据。
from sklearn.cross_validation import train_test_split

# 随机采样50%的数据用于测试，剩下的50%用于构建训练集合。
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=33)

from sklearn import linear_model

lr = linear_model.ElasticNetCV(l1_ratio=0.5,n_alphas=100000)
lr.fit(X_train,y_train)
y_pred_1 = lr.predict(X_test)
y_pred_0 = lr.predict(X_train)
print(lr.coef_)
print(lr.intercept_)
e_train = sum((y_pred_0 - y_train)**2) / (2*len(y_train))
print('error(train): %.3f' % ( sum((y_pred_0 - y_train)**2) / (2*len(y_train))))
print('error(train): %.3f' % ( sum((y_pred_1 - y_test)**2) / (2*len(y_test))))

# %%
plt.plot(range(600), lr.predict(np.array((range(600),[i*i for i in range(600)],[i*i*i for i in range(600)])).T), 'r-')
plt.scatter(X_train[:,0], y_train, marker='o',c = 'red')
plt.scatter(X_test[:,0], y_test, marker='x',c = 'black')
plt.xlabel("x")
plt.ylabel("y")
plt.savefig("./image/image_11.png") 
plt.show()
